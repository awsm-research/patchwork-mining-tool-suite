# %%
import pymongo
import requests
import re
import time

from pymongo import MongoClient
from pymongo import MongoClient
from pymongo.errors import DuplicateKeyError, CollectionInvalid
from threading import Thread
from dateutil import parser

# %%
NAME = ['kernel', 'ozlabs', 'ffmpeg']
CATEGORY = ['projects', 'series', 'patches']
INVALID_PAGE = {
    "detail": "Invalid page."
}

# %%
def get_database(username, password, database_name):
    # Provide the mongodb atlas url to connect python to mongodb using pymongo
    CONNECTION_STRING = f"mongodb+srv://{username}:{password}@cluster0.hls0ye8.mongodb.net/?retryWrites=true&w=majority"

    # Create a connection using MongoClient. You can import MongoClient or use pymongo.MongoClient
    client = MongoClient(CONNECTION_STRING)

    # Create the database for our example (we will use the same database throughout the tutorial
    return client[database_name]

# %%
# Get the database
username = 'default'
password = 'comp90055codereview'
database_name = 'code_review'
db = get_database(username, password, database_name)

# %%
# drop collections
# try:
#     db['project'].drop()
#     db['series'].drop()
#     db['patch'].drop()
#     db['comment'].drop()
#     db['account'].drop()
# except:
#     pass

# %%
try:
    project = db.create_collection('project')
    series = db.create_collection('series')
    patch = db.create_collection('patch')
    comment = db.create_collection('comment')
    account = db.create_collection('account')
except CollectionInvalid:
    pass
    # project = db['project']
    # series = db['series']
    # patch = db['patch']
    # comment = db['comment']
    # account = db['account']
db.list_collection_names()
# Out:
# ['account', 'comment', 'project', 'patch', 'series']

# %%
project.create_index([("original_id", pymongo.ASCENDING)],unique=True)
series.create_index([("original_id", pymongo.ASCENDING)],unique=True)
patch.create_index([("original_id", pymongo.ASCENDING)],unique=True)
comment.create_index([("original_id", pymongo.ASCENDING)],unique=True)
account.create_index([("original_id", pymongo.ASCENDING)],unique=True)
# Out:
# 'original_id_1'

# %%
def collection_insert_one(collection, item):
    try:
        collection.insert_one(item)
    except DuplicateKeyError:
        return

# %%
# t_url = 'https://patchwork.ffmpeg.org/api/patches/17384/'
# response = requests.get(t_url).json()
# response

# %%
# api_id, api_url, name, web_url = retrieve_basic_info(response['submitter'])
# print(api_id, api_url, name, web_url)

# %%
def retrieve_basic_info(json):
    api_id = 'id'
    api_url = 'url'
    name = 'name'
    web_url = 'web_url'
    
    info = [api_id, api_url, name, web_url]
    
    for i in range(len(info)):
        try:
            info[i] = json[info[i]]
        except KeyError:
            info[i] = None
    return info

# %%
# string = 'https://patchwork.ffmpeg.org/api/projects/'

# try:
#     found = re.search('https://patchwork\.(.*?)\.org', string).group(1)
#     print(found)
# except AttributeError:
#     print('error')

# 'A'.lower()

# %%
def retrieve_project_data(endpoint_name, json_project, database):
    # print(f"retrieving project: {json_project['url']}")
    # project info
    project_api_id, project_api_url, project_name, project_web_url = retrieve_basic_info(json_project)
    
    project_repo_url = json_project['webscm_url']
    project_list_id = json_project['list_id']
    project_list_address = json_project['list_email']
    project_original_id = '-'.join([endpoint_name, 'project', str(project_api_id)])

    # maintainer_info
    maintainers = json_project['maintainers']
    maintainer_list = list()
    for maintainer in maintainers:
        
        maintainer_api_id, maintainer_api_url, _, _ = retrieve_basic_info(maintainer)
        maintainer_username = maintainer['username']
        maintainer_email = maintainer['email']
        maintainer_original_id = '-'.join([endpoint_name, 'people', str(maintainer_api_id)])

        maintainer_list.append(maintainer_original_id)

        item_account = {
            'original_id': maintainer_original_id,
            'email': maintainer_email,
            'username': maintainer_username,
            'api_url': maintainer_api_url
        }

        collection_insert_one(database['account'], item_account)

    item_project = {
        'original_id': project_original_id,
        'name': project_name,
        'repo_url': project_repo_url,
        'list_id': project_list_id,
        'list_address': project_list_address,
        'web_url': project_web_url,
        'api_url': project_api_url,
        'maintainers': maintainer_list
    }

    collection_insert_one(database['project'], item_project)

# %%
def retrieve_series_data(endpoint_name, json_series, database):
    # print(f"retrieving series: {json_series['url']}")
    # series info
    series_api_id, series_api_url, series_name, series_web_url = retrieve_basic_info(json_series)
    series_created_date = parser.parse(json_series['date'])
    series_version = json_series['version']
    series_total = json_series['total']
    series_received_total = json_series['received_total']
    
    series_project_api_id, _, series_project_name, _ = retrieve_basic_info(json_series['project'])
    project_original_id = '-'.join([endpoint_name, 'project', str(series_project_api_id)])
    series_original_id = '-'.join([endpoint_name, 'series', str(series_api_id)])

    #get cover letter content
    if json_series['cover_letter']:
        cover_letter_url = json_series['cover_letter']['url']
        cover_detail = requests.get(cover_letter_url).json()
        # series_cover_letter_content = deactivate_quote(cover_detail['content'])
        series_cover_letter_content = cover_detail['content']
    else:
        series_cover_letter_content = ''

    # get project id
    # series_proj_original_id = json_series['project']['url'][:-1]

    # submitter info
    series_submitter_api_id, series_submitter_api_url, _, _ = retrieve_basic_info(json_series['submitter'])
    series_submitter_original_id = '-'.join([endpoint_name, 'people', str(series_submitter_api_id)])
    series_submitter_email = json_series['submitter']['email']
    series_submitter_name = json_series['submitter']['name']

    item_account = {
        'original_id': series_submitter_original_id,
        'email': series_submitter_email,
        'username': series_submitter_name,
        'api_url': series_submitter_api_url
    }

    collection_insert_one(database['account'], item_account)

    item_series = {
        'original_id': series_original_id,
        'name': series_name,
        'created_date': series_created_date,
        'version': series_version,
        'total': series_total,
        'received_total': series_received_total,
        'cover_letter_content': series_cover_letter_content,
        'project_original_id': project_original_id,
        'submitter_account_original_id': series_submitter_original_id,
        'web_url': series_web_url,
        'api_url': series_api_url
    }

    collection_insert_one(database['series'], item_series)

# %%
def retrieve_comment_data(endpoint_name, json_comment, project_original_id, patch_original_id, database):
    # print(f"retrieving comment, id: {json_comment['web_url']}")
    #comment info
    comment_api_id = json_comment['id']
    comment_original_id = '-'.join([endpoint_name, 'comment', str(comment_api_id)])
    comment_web_url = json_comment['web_url']
    comment_msg_id = json_comment['msgid']
    comment_msg_content = json_comment['content']
    comment_date = parser.parse(json_comment['date'])
    comment_subject = json_comment['subject']
    comment_reply_to_msg_id = ''
    if 'In-Reply-To' in json_comment['headers'].keys():
        in_reply_to = json_comment['headers']['In-Reply-To']
        if in_reply_to[:2] == '\n ':
            comment_reply_to_msg_id = in_reply_to[2:]

    # get submitter account id
    # insert account if not exist
    comment_submitter_api_id, comment_submitter_api_url, _, _ = retrieve_basic_info(json_comment['submitter'])
    comment_submitter_original_id = '-'.join([endpoint_name, 'people', str(comment_submitter_api_id)])
    comment_submitter_username = json_comment['submitter']['name']
    comment_submitter_email = json_comment['submitter']['email']

    item_account = {
        'original_id': comment_submitter_original_id,
        'email': comment_submitter_email,
        'username': comment_submitter_username,
        'api_url': comment_submitter_api_url
    }

    collection_insert_one(database['account'], item_account)

    item_comment = {
        'original_id': comment_original_id,
        'msg_id': comment_msg_id,
        'msg_content': comment_msg_content,
        'date': comment_date,
        'subject': comment_subject,
        'in_reply_to': comment_reply_to_msg_id,
        'project_original_id': project_original_id,
        'patch_original_id': patch_original_id,
        'submitter_account_original_id': comment_submitter_original_id,
        'change_id': '',
        'mailing_list_id': '',
        'web_url': comment_web_url
    }

    collection_insert_one(database['comment'], item_comment)

    # TODO get change id
    # TODO get mailing list id

# %%
def retrieve_patch_data(endpoint_name, json_patch, database):
    # print(f"retrieving patch {json_patch['url']}")
    #patch info
    patch_api_id, patch_api_url, patch_name, patch_web_url = retrieve_basic_info(json_patch)
    patch_project_original_id = '-'.join([endpoint_name, 'project', str(json_patch['project']['id'])])
    patch_original_id = '-'.join([endpoint_name, 'patch', str(patch_api_id)])
    
    patch_state = json_patch['state']
    patch_date = parser.parse(json_patch['date'])
    patch_msg_id = json_patch['msgid']
    patch_msg_content = json_patch['content']
    patch_code_diff = json_patch['diff']

    # TODO get change id
    # TODO get mailing list id

    # get series id
    if json_patch['series']:
        patch_series_api_id = json_patch['series']['id']
        patch_series_original_id = '-'.join([endpoint_name, 'series', str(patch_series_api_id)])
    else:
        patch_series_original_id = ''

    # submitter info
    patch_submitter_api_id, patch_submitter_api_url, _, _ = retrieve_basic_info(json_patch['submitter'])
    patch_submitter_original_id = '-'.join([endpoint_name, 'people', str(patch_submitter_api_id)])
    patch_submitter_username = json_patch['submitter']['name']
    patch_submitter_email = json_patch['submitter']['email']

    item_account = {
        'original_id': patch_submitter_original_id,
        'email': patch_submitter_email,
        'username': patch_submitter_username,
        'api_url': patch_submitter_api_url
    }

    collection_insert_one(database['account'], item_account)

    item_patch = {
        'original_id': patch_original_id,
        'name': patch_name,
        'state': patch_state,
        'date': patch_date,
        'msg_id': patch_msg_id,
        'msg_content': patch_msg_content,
        'code_diff': patch_code_diff,
        'project_original_id': patch_project_original_id,
        'series_original_id': patch_series_original_id,
        'submitter_account_original_id': patch_submitter_original_id,
        'change_id': '',
        'mailing_list_id': '',
        'api_url': patch_api_url,
        'web_url': patch_web_url
    }

    collection_insert_one(database['patch'], item_patch)

    comment_url = json_patch['comments']
    comment_list = requests.get(comment_url).json()
    if comment_list:
        for c in comment_list:
            retrieve_comment_data(endpoint_name, c, patch_project_original_id, patch_original_id, database)

# %%
# def retrieved_items(collection):
#     items = collection.find()
#     return [item['original_id'] for item in items]

# %%
MAX_THREAD = 6
PAGE_START = 0
BATCH = 250

def main_func(api_url_base, endpoint_name, database, entity_type, thread_no):
    page_num = PAGE_START + thread_no
    response = requests.get(api_url_base %(endpoint_name, entity_type, page_num)).json()

    retrieval_func = {
        'projects': retrieve_project_data,
        'series': retrieve_series_data,
        'patches': retrieve_patch_data
    }

    while response != INVALID_PAGE and page_num <= PAGE_START + BATCH:
        # print('%s: page%d started' %entity_type)
        p_start_time = time.time()

        for entity in response:
            entity_api_url = entity['url']
            entity_detail = requests.get(entity_api_url).json()

            retrieval_func[entity_type](endpoint_name, entity_detail, database)
        
        total_time = time.time() - p_start_time
        print('%s:\tpage%d\tcompleted in %.2f s' %(entity_type, page_num, total_time))

        page_num += MAX_THREAD
        response = requests.get(api_url_base %(endpoint_name, entity_type, page_num)).json()

def crawl_entity(api_url_base, endpoint_name, database, entity_type):
    # page_num = 1
    # api_url = api_url_base %(endpoint_name, entity_type, page_num)
    # thread1 = Thread(target=main_func, args=(api_url_base, endpoint_name, database, entity_type, 1))
    # thread2 = Thread(target=main_func, args=(api_url_base, endpoint_name, database, entity_type, 2))
    
    # thread1.start()
    # thread2.start()
    
    threads = [Thread(target=main_func, args=(api_url_base, endpoint_name, database, entity_type, thread_no)) for thread_no in range(1, MAX_THREAD + 1)]
    for thread in threads:
        thread.start()
    
    for thread in threads:
        thread.join()
    # main_func(api_url_base, endpoint_name, database, entity_type, 1)

# %%
def crawl_data(endpoint_name, database):
    start_time = time.time()
    api_url_base = 'https://patchwork.%s.org/api/%s/?page=%d'
    entity_types = ['projects', 'series', 'patches']
    # entity_types = ['series']
    
#     threads = [Thread(target=crawl_entity, args=(api_url_base, endpoint_name, database, entity_type)) for entity_type in entity_types]
    
#     for thread in threads:
#         thread.start()
        
#     for thread in threads:
#         thread.join()

    [crawl_entity(api_url_base, endpoint_name, database, entity_type) for entity_type in entity_types]
    
    duration = (time.time() - start_time) / 60
    print('Retrieval completed in %.2f min' %duration)

# %%
# for cate in CATEGORY:
#     crawl_data(NAME[2], cate)
crawl_data(NAME[2], db)
# Out:
# projects:	page1	completed in 1.98 s
# series:	page2	completed in 46.66 s
# series:	page3	completed in 46.24 s
# series:	page1	completed in 50.59 s
# series:	page5	completed in 50.44 s
# series:	page6	completed in 50.91 s
# series:	page4	completed in 53.37 s
# series:	page8	completed in 44.04 s
# series:	page9	completed in 46.59 s
# series:	page11	completed in 44.15 s
# series:	page12	completed in 45.35 s
# series:	page7	completed in 46.89 s
# series:	page10	completed in 46.70 s
# series:	page14	completed in 47.07 s
# series:	page15	completed in 44.56 s
# series:	page18	completed in 44.04 s
# series:	page13	completed in 48.50 s
# series:	page17	completed in 50.92 s
# series:	page16	completed in 50.07 s
# series:	page20	completed in 49.24 s
# series:	page21	completed in 48.91 s
# series:	page24	completed in 47.49 s
# series:	page19	completed in 47.51 s
# series:	page23	completed in 48.16 s
# series:	page22	completed in 49.58 s
# series:	page26	completed in 49.36 s
# series:	page30	completed in 47.97 s
# series:	page27	completed in 49.17 s
# series:	page25	completed in 46.41 s
# series:	page29	completed in 47.25 s
# series:	page28	completed in 44.64 s
# series:	page32	completed in 46.98 s
# series:	page33	completed in 46.71 s
# series:	page36	completed in 49.67 s
# series:	page31	completed in 47.32 s
# series:	page35	completed in 49.83 s
# series:	page34	completed in 54.26 s
# series:	page39	completed in 48.21 s
# series:	page38	completed in 51.12 s
# series:	page42	completed in 48.14 s
# series:	page37	completed in 48.27 s
# series:	page41	completed in 45.47 s
# series:	page40	completed in 43.96 s
# series:	page45	completed in 47.98 s
# series:	page43	completed in 46.51 s
# series:	page44	completed in 49.92 s
# series:	page48	completed in 49.72 s
# series:	page47	completed in 48.78 s
# series:	page46	completed in 47.28 s
# series:	page51	completed in 47.52 s
# series:	page49	completed in 49.38 s
# series:	page50	completed in 47.21 s
# series:	page54	completed in 46.96 s
# series:	page53	completed in 47.83 s
# series:	page52	completed in 49.96 s
# series:	page57	completed in 49.37 s
# series:	page60	completed in 45.82 s
# series:	page55	completed in 46.19 s
# series:	page56	completed in 48.75 s
# series:	page59	completed in 46.30 s
# series:	page58	completed in 48.45 s
# series:	page61	completed in 45.21 s
# series:	page66	completed in 45.51 s
# series:	page62	completed in 44.18 s
# series:	page63	completed in 48.48 s
# series:	page65	completed in 49.94 s
# series:	page64	completed in 45.48 s
# series:	page67	completed in 45.67 s
# series:	page72	completed in 46.80 s
# series:	page68	completed in 45.94 s
# series:	page69	completed in 51.01 s
# series:	page71	completed in 47.76 s
# series:	page70	completed in 47.03 s
# series:	page78	completed in 46.94 s
# series:	page73	completed in 48.45 s
# series:	page74	completed in 50.90 s
# series:	page75	completed in 47.23 s
# series:	page76	completed in 49.86 s
# series:	page77	completed in 52.66 s
# series:	page84	completed in 45.72 s
# series:	page79	completed in 48.11 s
# series:	page81	completed in 44.41 s
# series:	page80	completed in 48.71 s
# series:	page83	completed in 45.19 s
# series:	page82	completed in 47.70 s
# series:	page85	completed in 46.16 s
# series:	page90	completed in 52.09 s
# series:	page87	completed in 50.68 s
# series:	page86	completed in 51.03 s
# series:	page88	completed in 45.99 s
# series:	page89	completed in 47.99 s
# series:	page91	completed in 49.48 s
# series:	page96	completed in 50.84 s
# series:	page92	completed in 46.70 s
# series:	page95	completed in 45.56 s
# series:	page93	completed in 51.99 s
# series:	page94	completed in 47.74 s
# series:	page97	completed in 51.26 s
# series:	page98	completed in 46.96 s
# series:	page99	completed in 47.55 s
# series:	page102	completed in 53.38 s
# series:	page101	completed in 50.76 s
# series:	page100	completed in 51.36 s
# series:	page103	completed in 48.27 s
# series:	page104	completed in 49.08 s
# series:	page105	completed in 48.30 s
# series:	page107	completed in 47.08 s
# series:	page108	completed in 49.01 s
# series:	page106	completed in 49.76 s
# series:	page109	completed in 52.69 s
# series:	page110	completed in 52.64 s
# series:	page114	completed in 52.17 s
# series:	page111	completed in 55.48 s
# series:	page113	completed in 55.43 s
# series:	page112	completed in 54.17 s
# series:	page115	completed in 46.67 s
# series:	page116	completed in 47.47 s
# series:	page120	completed in 45.42 s
# series:	page119	completed in 44.89 s
# series:	page117	completed in 47.94 s
# series:	page118	completed in 47.65 s
# series:	page121	completed in 51.35 s
# series:	page122	completed in 52.61 s
# series:	page126	completed in 51.96 s
# series:	page125	completed in 49.92 s
# series:	page123	completed in 51.08 s
# series:	page124	completed in 51.40 s
# series:	page127	completed in 52.86 s
# series:	page128	completed in 50.09 s
# series:	page131	completed in 49.40 s
# series:	page132	completed in 50.11 s
# series:	page129	completed in 50.90 s
# series:	page130	completed in 48.37 s
# series:	page134	completed in 45.05 s
# series:	page138	completed in 45.29 s
# series:	page133	completed in 50.05 s
# series:	page135	completed in 46.73 s
# series:	page136	completed in 46.13 s
# series:	page137	completed in 52.93 s
# series:	page144	completed in 47.71 s
# series:	page140	completed in 50.80 s
# series:	page139	completed in 49.27 s
# series:	page141	completed in 47.93 s
# series:	page142	completed in 49.46 s
# series:	page143	completed in 49.34 s
# series:	page150	completed in 45.81 s
# series:	page146	completed in 46.89 s
# series:	page145	completed in 48.70 s
# series:	page148	completed in 45.07 s
# series:	page147	completed in 48.19 s
# series:	page149	completed in 47.06 s
# series:	page156	completed in 48.09 s
# series:	page152	completed in 46.65 s
# series:	page151	completed in 47.38 s
# series:	page153	completed in 47.07 s
# series:	page155	completed in 49.70 s
# series:	page154	completed in 52.04 s
# series:	page162	completed in 49.11 s
# series:	page158	completed in 49.23 s
# series:	page159	completed in 46.88 s
# series:	page157	completed in 50.60 s
# series:	page160	completed in 49.68 s
# series:	page161	completed in 50.22 s
# series:	page164	completed in 46.27 s
# series:	page168	completed in 49.46 s
# series:	page163	completed in 48.85 s
# series:	page165	completed in 51.76 s
# series:	page166	completed in 44.89 s
# series:	page167	completed in 48.20 s
# series:	page174	completed in 45.51 s
# series:	page170	completed in 49.84 s
# series:	page172	completed in 46.51 s
# series:	page169	completed in 48.25 s
# series:	page171	completed in 50.54 s
# series:	page173	completed in 47.19 s
# series:	page180	completed in 45.55 s
# series:	page176	completed in 45.76 s
# series:	page175	completed in 47.01 s
# series:	page178	completed in 50.96 s
# series:	page177	completed in 50.28 s
# series:	page179	completed in 51.09 s
# series:	page186	completed in 48.83 s
# series:	page182	completed in 50.64 s
# series:	page184	completed in 48.37 s
# series:	page181	completed in 53.72 s
# series:	page185	completed in 46.82 s
# series:	page183	completed in 51.29 s
# series:	page192	completed in 50.85 s
# series:	page188	completed in 54.13 s
# series:	page187	completed in 46.90 s
# series:	page190	completed in 49.31 s
# series:	page189	completed in 50.50 s
# series:	page191	completed in 52.24 s
# series:	page198	completed in 51.99 s
# series:	page194	completed in 49.95 s
# series:	page193	completed in 53.13 s
# series:	page197	completed in 48.17 s
# series:	page195	completed in 49.71 s
# series:	page196	completed in 57.62 s
# series:	page204	completed in 50.63 s
# series:	page200	completed in 53.88 s
# series:	page199	completed in 54.02 s
# series:	page203	completed in 51.74 s
# series:	page201	completed in 52.45 s
# series:	page202	completed in 52.68 s
# series:	page210	completed in 50.95 s
# series:	page206	completed in 47.09 s
# series:	page205	completed in 43.90 s
# series:	page209	completed in 45.94 s
# series:	page207	completed in 44.49 s
# series:	page208	completed in 47.60 s
# series:	page216	completed in 51.39 s
# series:	page211	completed in 48.70 s
# series:	page212	completed in 56.83 s
# series:	page213	completed in 53.36 s
# series:	page215	completed in 53.77 s
# series:	page214	completed in 53.80 s
# series:	page217	completed in 47.77 s
# series:	page222	completed in 59.25 s
# series:	page218	completed in 56.59 s
# series:	page219	completed in 54.96 s
# series:	page221	completed in 54.84 s
# series:	page220	completed in 50.62 s
# series:	page223	completed in 57.93 s
# series:	page228	completed in 50.60 s
# series:	page226	completed in 46.60 s
# series:	page227	completed in 48.99 s
# series:	page224	completed in 54.56 s
# series:	page225	completed in 53.96 s
# series:	page234	completed in 48.61 s
# series:	page229	completed in 48.98 s
# series:	page233	completed in 46.53 s
# series:	page232	completed in 48.66 s
# series:	page230	completed in 48.71 s
# series:	page231	completed in 51.54 s
# series:	page240	completed in 50.11 s
# series:	page235	completed in 49.82 s
# series:	page239	completed in 53.10 s
# series:	page238	completed in 52.92 s
# series:	page236	completed in 57.22 s
# series:	page237	completed in 54.28 s
# series:	page243	completed in 1.47 s
# series:	page241	completed in 59.76 s
# series:	page242	completed in 58.36 s
# patches:	page3	completed in 98.07 s
# patches:	page1	completed in 97.18 s
# patches:	page4	completed in 100.47 s
# patches:	page5	completed in 97.81 s
# patches:	page6	completed in 100.52 s
# patches:	page2	completed in 105.80 s
# patches:	page9	completed in 95.27 s
# patches:	page10	completed in 97.14 s
# patches:	page11	completed in 96.33 s
# patches:	page12	completed in 94.42 s
# patches:	page7	completed in 103.21 s
# patches:	page8	completed in 97.64 s
# patches:	page15	completed in 96.90 s
# patches:	page17	completed in 94.55 s
# patches:	page18	completed in 96.51 s
# patches:	page16	completed in 101.22 s
# patches:	page13	completed in 97.34 s
# patches:	page14	completed in 99.85 s
# patches:	page23	completed in 95.26 s
# patches:	page24	completed in 95.21 s
# patches:	page22	completed in 92.97 s
# patches:	page21	completed in 101.11 s
# patches:	page19	completed in 100.68 s
# patches:	page20	completed in 98.34 s
# patches:	page29	completed in 93.98 s
# patches:	page28	completed in 93.73 s
# patches:	page30	completed in 94.84 s
# patches:	page27	completed in 96.07 s
# patches:	page25	completed in 97.75 s
# patches:	page26	completed in 96.99 s
# patches:	page34	completed in 97.87 s
# patches:	page36	completed in 98.16 s
# patches:	page35	completed in 101.70 s
# patches:	page33	completed in 101.02 s
# patches:	page31	completed in 95.94 s
# patches:	page32	completed in 99.85 s
# patches:	page39	completed in 99.89 s
# patches:	page41	completed in 105.48 s
# patches:	page42	completed in 106.94 s
# patches:	page40	completed in 110.28 s
# patches:	page37	completed in 103.26 s
# patches:	page38	completed in 106.60 s
# patches:	page47	completed in 94.56 s
# patches:	page45	completed in 95.57 s
# patches:	page48	completed in 95.02 s
# patches:	page46	completed in 94.47 s
# patches:	page43	completed in 97.35 s
# patches:	page44	completed in 93.49 s
# patches:	page52	completed in 92.34 s
# patches:	page51	completed in 96.62 s
# patches:	page54	completed in 96.00 s
# patches:	page53	completed in 100.95 s
# patches:	page49	completed in 100.91 s
# patches:	page50	completed in 109.24 s
# patches:	page57	completed in 104.86 s
# patches:	page60	completed in 105.31 s
# patches:	page58	completed in 108.92 s
# patches:	page55	completed in 98.10 s
# patches:	page59	completed in 113.66 s
# patches:	page56	completed in 99.61 s
# patches:	page63	completed in 103.51 s
# patches:	page66	completed in 102.22 s
# patches:	page64	completed in 104.77 s
# patches:	page61	completed in 103.72 s
# patches:	page65	completed in 105.46 s
# patches:	page62	completed in 106.67 s
# patches:	page69	completed in 91.38 s
# patches:	page72	completed in 91.92 s
# patches:	page70	completed in 94.99 s
# patches:	page67	completed in 93.12 s
# patches:	page71	completed in 92.10 s
# patches:	page68	completed in 94.67 s
# patches:	page75	completed in 92.60 s
# patches:	page78	completed in 98.05 s
# patches:	page76	completed in 94.69 s
# patches:	page73	completed in 95.73 s
# patches:	page77	completed in 92.98 s
# patches:	page74	completed in 92.67 s
# patches:	page81	completed in 100.70 s
# patches:	page82	completed in 94.19 s
# patches:	page84	completed in 99.10 s
# patches:	page83	completed in 94.11 s
# patches:	page79	completed in 98.20 s
# patches:	page80	completed in 97.94 s
# patches:	page87	completed in 98.33 s
# patches:	page88	completed in 99.86 s
# patches:	page90	completed in 97.72 s
# patches:	page89	completed in 101.03 s
# patches:	page85	completed in 102.24 s
# patches:	page86	completed in 98.26 s
# patches:	page93	completed in 96.23 s
# patches:	page94	completed in 93.40 s
# patches:	page96	completed in 97.71 s
# patches:	page95	completed in 95.04 s
# patches:	page91	completed in 96.80 s
# patches:	page92	completed in 94.23 s
# patches:	page100	completed in 90.69 s
# patches:	page99	completed in 96.03 s
# patches:	page102	completed in 98.12 s
# patches:	page101	completed in 94.62 s
# patches:	page97	completed in 95.21 s
# patches:	page98	completed in 95.84 s
# patches:	page106	completed in 97.00 s
# patches:	page105	completed in 96.72 s
# patches:	page108	completed in 98.82 s
# patches:	page107	completed in 98.05 s
# patches:	page103	completed in 97.24 s
# patches:	page104	completed in 101.65 s
# patches:	page112	completed in 101.04 s
# patches:	page111	completed in 96.93 s
# patches:	page114	completed in 98.72 s
# patches:	page113	completed in 98.30 s
# patches:	page109	completed in 97.89 s
# patches:	page110	completed in 100.19 s
# patches:	page118	completed in 96.82 s
# patches:	page117	completed in 98.71 s
# patches:	page119	completed in 99.16 s
# patches:	page115	completed in 96.12 s
# patches:	page120	completed in 101.40 s
# patches:	page116	completed in 92.07 s
# patches:	page124	completed in 99.95 s
# patches:	page123	completed in 97.74 s
# patches:	page121	completed in 99.51 s
# patches:	page125	completed in 101.43 s
# patches:	page126	completed in 102.68 s
# patches:	page122	completed in 99.65 s
# patches:	page129	completed in 92.84 s
# patches:	page130	completed in 96.53 s
# patches:	page127	completed in 92.93 s
# patches:	page131	completed in 94.06 s
# patches:	page132	completed in 92.44 s
# patches:	page128	completed in 95.44 s
# patches:	page135	completed in 96.17 s
# patches:	page136	completed in 96.11 s
# patches:	page133	completed in 97.36 s
# patches:	page137	completed in 95.67 s
# patches:	page138	completed in 98.98 s
# patches:	page134	completed in 95.31 s
# patches:	page141	completed in 98.18 s
# patches:	page142	completed in 97.07 s
# patches:	page139	completed in 95.86 s
# patches:	page143	completed in 93.99 s
# patches:	page144	completed in 96.75 s
# patches:	page140	completed in 102.88 s
# patches:	page147	completed in 99.03 s
# patches:	page148	completed in 97.76 s
# patches:	page145	completed in 99.97 s
# patches:	page149	completed in 99.14 s
# patches:	page150	completed in 101.68 s
# patches:	page146	completed in 96.69 s
# patches:	page153	completed in 102.50 s
# patches:	page154	completed in 107.05 s
# patches:	page151	completed in 96.17 s
# patches:	page155	completed in 99.91 s
# patches:	page156	completed in 100.76 s
# patches:	page152	completed in 100.87 s
# patches:	page159	completed in 96.36 s
# patches:	page157	completed in 96.07 s
# patches:	page160	completed in 98.24 s
# patches:	page161	completed in 96.90 s
# patches:	page158	completed in 97.09 s
# patches:	page162	completed in 107.25 s
# patches:	page165	completed in 102.49 s
# patches:	page163	completed in 98.33 s
# patches:	page166	completed in 101.72 s
# patches:	page167	completed in 100.46 s
# patches:	page164	completed in 98.07 s
# patches:	page168	completed in 98.36 s
# patches:	page171	completed in 102.45 s
# patches:	page172	completed in 104.06 s
# patches:	page169	completed in 107.88 s
# patches:	page173	completed in 106.71 s
# patches:	page170	completed in 106.06 s
# patches:	page174	completed in 110.05 s
# patches:	page177	completed in 110.18 s
# patches:	page175	completed in 108.12 s
# patches:	page178	completed in 115.53 s
# patches:	page179	completed in 113.69 s
# patches:	page176	completed in 108.89 s
# patches:	page180	completed in 111.02 s
# patches:	page183	completed in 96.58 s
# patches:	page181	completed in 101.78 s
# patches:	page184	completed in 96.67 s
# patches:	page185	completed in 97.10 s
# patches:	page182	completed in 97.82 s
# patches:	page186	completed in 93.80 s
# patches:	page189	completed in 99.40 s
# patches:	page190	completed in 94.95 s
# patches:	page187	completed in 96.05 s
# patches:	page191	completed in 101.80 s
# patches:	page188	completed in 101.14 s
# patches:	page192	completed in 94.97 s
# patches:	page195	completed in 102.90 s
# patches:	page193	completed in 106.41 s
# patches:	page196	completed in 107.74 s
# patches:	page197	completed in 104.82 s
# patches:	page198	completed in 99.54 s
# patches:	page194	completed in 100.75 s
# patches:	page201	completed in 102.18 s
# patches:	page199	completed in 99.67 s
# patches:	page202	completed in 104.30 s
# patches:	page203	completed in 105.11 s
# patches:	page200	completed in 102.03 s
# patches:	page204	completed in 111.78 s
# patches:	page207	completed in 100.89 s
# patches:	page208	completed in 95.37 s
# patches:	page205	completed in 104.46 s
# patches:	page209	completed in 100.39 s
# patches:	page206	completed in 100.03 s
# patches:	page210	completed in 101.04 s
# patches:	page213	completed in 100.71 s
# patches:	page214	completed in 95.96 s
# patches:	page211	completed in 96.48 s
# patches:	page212	completed in 91.05 s
# patches:	page215	completed in 93.11 s
# patches:	page216	completed in 95.72 s
# patches:	page219	completed in 99.78 s
# patches:	page220	completed in 97.62 s
# patches:	page217	completed in 98.64 s
# patches:	page221	completed in 93.81 s
# patches:	page218	completed in 98.70 s
# patches:	page222	completed in 95.77 s
# patches:	page225	completed in 99.06 s
# patches:	page226	completed in 99.24 s
# patches:	page223	completed in 98.15 s
# patches:	page227	completed in 100.21 s
# patches:	page224	completed in 97.48 s
# patches:	page228	completed in 97.66 s
# patches:	page231	completed in 100.52 s
# patches:	page232	completed in 100.73 s
# patches:	page229	completed in 100.41 s
# patches:	page233	completed in 97.10 s
# patches:	page230	completed in 98.46 s
# patches:	page234	completed in 99.77 s
# patches:	page237	completed in 95.53 s
# patches:	page238	completed in 95.61 s
# patches:	page235	completed in 99.06 s
# patches:	page236	completed in 95.97 s
# patches:	page239	completed in 98.83 s
# patches:	page240	completed in 98.78 s
# patches:	page244	completed in 98.31 s
# patches:	page243	completed in 102.69 s
# patches:	page241	completed in 97.42 s
# patches:	page245	completed in 100.72 s
# patches:	page242	completed in 102.33 s
# patches:	page246	completed in 98.05 s
# patches:	page250	completed in 103.78 s
# patches:	page247	completed in 102.37 s
# patches:	page249	completed in 111.24 s
# patches:	page248	completed in 102.25 s
# Retrieval completed in 106.55 min
